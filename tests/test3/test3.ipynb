# %%
from test3 import test3

# %%
test3(mech_type='laplace', query_type='wage')

# %%
test3(mech_type='laplace', query_type='combined')

# %%
test3(mech_type='laplace', query_type='histogram')

# %%
test3(mech_type='gaussian', query_type='wage')

# %%
test3(mech_type='gaussian', query_type='combined')

# %%
test3(mech_type='gaussian', query_type='histogram')
