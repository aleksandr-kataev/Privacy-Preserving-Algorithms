# %%
from math import sqrt
from test1 import test1

# %%
test1(mech_type='laplace', query_type='wage', epsilon=1, sensitivity=1, num_of_runs=20)
# Out:
# Run number:  2
# 200 individuals value:  26.16182013669336
# 199 individuals value:  28.775558665400496
# Upper limit:  71.1152002769875
# Satisfies the definition of differential privacy

# %%
test1(mech_type='laplace', query_type='combined', epsilon=1, sensitivity=2, num_of_runs=20)
# Out:
# Run number:  13
# 200 individuals value:  85.89093147593711
# 199 individuals value:  101.2326072843641
# Upper limit:  233.47575826046088
# Satisfies the definition of differential privacy

# %%
test1(mech_type='gaussian', query_type='wage', epsilon=1, sensitivity=1, num_of_runs=20)
# Out:
# Run number:  1
# 200 individuals value:  30.65312807853058
# 199 individuals value:  20.194608556616352
# Upper limit:  54.899637472293776
# Satisfies the definition of differential privacy

# %%
test1(mech_type='gaussian', query_type='combined', epsilon=1, sensitivity=sqrt(2), num_of_runs=20)
# Out:
# Run number:  15
# 200 individuals value:  114.58471394939161
# 199 individuals value:  92.67082881728645
# Upper limit:  251.91043000226858
# Satisfies the definition of differential privacy
