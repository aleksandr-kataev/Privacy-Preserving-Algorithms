# %%
from experiment3 import experiment3

# %%
experiment3(mech_type='laplace', query_type='wage')

# %%
experiment3(mech_type='laplace', query_type='combined')

# %%
experiment3(mech_type='laplace', query_type='histogram')

# %%
experiment3(mech_type='gaussian', query_type='wage')

# %%
experiment3(mech_type='gaussian', query_type='combined')

# %%
experiment3(mech_type='gaussian', query_type='histogram')
