# %%
from math import sqrt
from experiment1 import experiment1

# %%
experiment1(mech_type='laplace', query_type='wage', epsilon=1, sensitivity=1, num_of_runs=20)
# Out:
# Run number:  8
# 200 individuals value:  29.126534625397923
# 199 individuals value:  23.748869012820673
# Upper limit:  64.55611908400454
# Satisfies the definition of differential privacy

# %%
experiment1(mech_type='laplace', query_type='combined', epsilon=1, sensitivity=2, num_of_runs=20)
# Out:
# Run number:  11
# 200 individuals value:  114.72750248262946
# 199 individuals value:  101.32229202807463
# Upper limit:  275.422545237736
# Satisfies the definition of differential privacy

# %%
experiment1(mech_type='gaussian', query_type='wage', epsilon=1, sensitivity=1, num_of_runs=20)
# Out:
# Run number:  18
# 200 individuals value:  25.30538153067809
# 199 individuals value:  33.25772442990392
# Upper limit:  68.79215877706538
# Satisfies the definition of differential privacy

# %%
experiment1(mech_type='gaussian', query_type='combined', epsilon=1, sensitivity=sqrt(2), num_of_runs=20)
# Out:
# Run number:  14
# 200 individuals value:  110.13230557543122
# 199 individuals value:  96.33326400891089
# Upper limit:  261.8659610315702
# Satisfies the definition of differential privacy
